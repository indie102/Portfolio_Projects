# %%
import requests
from bs4 import BeautifulSoup
import random
import pandas as pd

# %%
collection_url = "https://www.sportsfuel.co.nz/collections/protein-powder?sortBy=best_match&page={}"
response = requests.get(collection_url)

# %%
response
# Out:
# <Response [200]>

# %%
import time

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
                  "(KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}
all_products = []


for page in range(1, 4): 
    print(f"Scraping page {page}...")
    url = collection_url.format(page)
    response = requests.get(url, headers=headers)
    
    if response.status_code != 200:
        print(f"Failed to fetch page {page}")
        break

    soup = BeautifulSoup(response.text, "html.parser")
    product_cards = soup.find_all("a", class_="Product_product__wb3tB")

    for card in product_cards:
        try:
            
            product_name = card.find("div", class_="Product_product__title__8lGN8").text.strip()
            product_type = card.find("div", class_="Product_product__type__Nk6Ig").text.strip()
        
            # Price
            price = card.find("span", class_="Product_product__price__5Hug4").text.strip()
            compare_price_span = card.find("span", class_="Product_product__compare-at__kgfns")
            compare_price = compare_price_span.text.strip() if compare_price_span else None

            # Flavours
            options = card.find("div", class_="Product_product__options__IsdYk")
            options_text = options.text.strip() if options else None

            all_products.append({
                "name": product_name,
                "type": product_type,
                "price": price,
                "compare_price": compare_price,
                "options": options_text
            })

        except Exception as e:
            print("Error parsing product:", e)
            continue

    time.sleep(random.uniform(2, 5)) 

print(f"\nScraped {len(all_products)} products.\n")

# first 3 products
for product in all_products[:3]:
    print(product)
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...
#
# Scraped 0 products.

# %% [markdown]
# #### SportsFuel.co.nz loads data dynamically ie. JavaScript runs in the browser to fill in content after the initial page loads.
# #### One of the solutions is to use a headless browser (can render the web pages as they would appear in a normal browser, and execute the JavaScript code.) libraries to work with a headless browser are Selenium or Puppeteer.
# #### Selenium mimics the actions of a real user interacting with a website, making it an excellent choice for scraping dynamic pages that rely heavily on JavaScript.

# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in /opt/anaconda3/lib/python3.12/site-packages (4.32.0)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.3)
# Requirement already satisfied: trio~=0.17 in /opt/anaconda3/lib/python3.12/site-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.9 in /opt/anaconda3/lib/python3.12/site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2021.10.8 in /opt/anaconda3/lib/python3.12/site-packages (from selenium) (2025.4.26)
# Requirement already satisfied: typing_extensions~=4.9 in /opt/anaconda3/lib/python3.12/site-packages (from selenium) (4.11.0)
# Requirement already satisfied: websocket-client~=1.8 in /opt/anaconda3/lib/python3.12/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from trio~=0.17->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in /opt/anaconda3/lib/python3.12/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.12/site-packages (from trio~=0.17->selenium) (3.7)
# Requirement already satisfied: outcome in /opt/anaconda3/lib/python3.12/site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: wsproto>=0.14 in /opt/anaconda3/lib/python3.12/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /opt/anaconda3/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time
import random

# headless mode means that the browser window wouldn’t be visible.
options = Options()
options.headless = True
driver = webdriver.Chrome(options=options)

base_url = "https://www.sportsfuel.co.nz/collections/protein-powder?sort_by=best_match&page={}"
all_products = []


for page in range(1, 4): 
    url = base_url.format(page)
    print(f"Scraping page {page}...")
    driver.get(url)
    # To avoid detection as a bot, used random delays
    time.sleep(random.uniform(3, 5)) 

    soup = BeautifulSoup(driver.page_source, "html.parser")
    product_cards = soup.find_all("a", class_="Product_product__wb3tB")

    for card in product_cards:
        try:
            product_name = card.find("div", class_="Product_product__title__8lGN8").text.strip()
            product_type = card.find("div", class_="Product_product__type__Nk6Ig").text.strip()
            product_url = "https://www.sportsfuel.co.nz" + card["href"]

            price = card.find("span", class_="Product_product__price__5Hug4").text.strip()
            compare_price_span = card.find("span", class_="Product_product__compare-at__kgfns")
            compare_price = compare_price_span.text.strip() if compare_price_span else None

            options_div = card.find("div", class_="Product_product__options__IsdYk")
            options = options_div.text.strip() if options_div else None


            all_products.append({
                "name": product_name,
                "type": product_type,
                "price": price,
                "compare_price": compare_price,
                "options": options,
                "url": product_url
            })

        except Exception as e:
            print("Product not found", e)
            continue

driver.quit()

print(f"\nScraped {len(all_products)} products.\n")
for p in all_products[:3]:
    print(p)
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...
#
# Scraped 120 products.
#
# {'name': 'Optimum Nutrition Gold Standard 100% Whey Protein Powder', 'type': 'Whey Protein', 'price': '$47.95', 'compare_price': '$59.94', 'options': '5 Sizes | 22 Flavours', 'url': 'https://www.sportsfuel.co.nz/products/optimum-gold-standard-100-whey-protein'}
# {'name': 'Clean Nutrition Whey Protein Powder 1kg', 'type': 'Whey Protein', 'price': '$49.46', 'compare_price': '$54.95', 'options': '7 Flavours', 'url': 'https://www.sportsfuel.co.nz/products/clean-nutrition-whey-protein-1kg'}
# {'name': 'Clean Nutrition Whey Protein Powder 2kg', 'type': 'Whey Protein', 'price': '$98.91', 'compare_price': '$109.90', 'options': '1 Sizes', 'url': 'https://www.sportsfuel.co.nz/products/clean-nutrition-whey-protein-2kg'}

# %%
import pandas as pd

df = pd.DataFrame(all_products)

pd.set_option("display.max_rows", None)
df
# Out:
#                                                   name                  type  \
# 0    Optimum Nutrition Gold Standard 100% Whey Prot...          Whey Protein
# 1              Clean Nutrition Whey Protein Powder 1kg          Whey Protein
# 2              Clean Nutrition Whey Protein Powder 2kg          Whey Protein
# 3    Optimum Nutrition Gold Standard 100% Whey Isolate  Whey Protein Isolate
# 4               Clean Nutrition Pea Protein Powder 1kg         Plant Protein
# 5    MuscleTech Nitro Tech 100% Whey Gold Protein P...          Whey Protein
# 6                    MuscleTech IsoWhey Protein Powder  Whey Protein Isolate
# 7                     Rule 1 Whey Blend Protein Powder          Whey Protein
# 8                   Rule 1 Whey Isolate Protein Powder  Whey Protein Isolate
# 9                  Musashi Shred & Burn Protein Powder          Whey Protein
# 10              Clean Nutrition Pea Protein Powder 2kg         Plant Protein
# 11                     Musashi High Protein Powder 2kg          Whey Protein
# 12       Mitchells Nutrition Bone Broth Protein Powder          Beef Protein
# 13                       Nuzest Clean Lean Protein 1kg         Plant Protein
# 14     PVL ISOGOLD Premium Whey Isolate Protein Powder  Whey Protein Isolate
# 15   Optimum Nutrition Serious Mass Protein Powder ...           Mass Gainer
# 104                      Mutant Mass Extreme 2500 12lb           Mass Gainer
# 105  Optimum Nutrition Gold Standard 100% Casein Pr...        Casein Protein
# 106                   Musashi High Protein Powder 900g          Whey Protein
# 107                  Pack Nutrition Feral Whey Protein          Whey Protein
# 108  Balance Naturals Ultra Ripped Whey Protein Pow...          Whey Protein
# 109                    Horleys ICE Whey Protein Powder          Whey Protein
# 110                         PranaOn Phyto Fire Protein         Plant Protein
# 111                          Balance Plant Protein 1kg         Plant Protein
# 112               Macro Mike Plant Protein Sample Pack         Plant Protein
# 113             BSN Syntha 6 Edge Protein Powder 3.7lb          Whey Protein
# 114                   Switch Nutrition Collagen Switch              Collagen
# 115                       Nothing Naughty Collagen Bar              Collagen
# 116                         MuscleTech Mass Tech Elite           Mass Gainer
# 117           EHP Labs IsoPept Whey Protein Powder 2lb  Whey Protein Isolate
# 118                 EHP Labs Blessed Plant Protein 2lb         Plant Protein
# 119                  Clean Nutrition Fava Bean Protein         Plant Protein
#
#        price compare_price                options  \
# 0     $47.95        $59.94  5 Sizes | 22 Flavours
# 1     $49.46        $54.95             7 Flavours
# 2     $98.91       $109.90                1 Sizes
# 3     $79.95        $99.94   3 Sizes | 3 Flavours
# 4     $37.71        $41.90             4 Flavours
# 5    $125.96       $139.95   1 Sizes | 7 Flavours
# 6     $74.66        $82.95   2 Sizes | 2 Flavours
# 7     $27.97        $39.95  4 Sizes | 11 Flavours
# 8     $34.97        $49.95  3 Sizes | 11 Flavours
# 9     $27.19        $33.99   3 Sizes | 2 Flavours
# 10    $75.42        $83.80                1 Sizes
# 11    $94.35       $117.94             2 Flavours
# 12     $5.94         $6.60   2 Sizes | 5 Flavours
# 13    $71.95        $89.94             5 Flavours
# 14   $152.96       $169.95   1 Sizes | 8 Flavours
# 15   $127.95       $159.94             4 Flavours
# 16    $55.21        $84.94  2 Sizes | 10 Flavours
# 17   $151.95       $189.94             2 Flavours
# 18    $89.09        $98.99             5 Flavours
# 19   $143.96       $159.95             5 Flavours
# 20    $45.86        $50.95             6 Flavours
# 21    $44.96        $49.95             1 Flavours
# 22    $67.95        $84.94             7 Flavours
# 23    $71.96        $79.95             2 Flavours
# 24    $47.95        $59.94  5 Sizes | 22 Flavours
# 25    $49.46        $54.95             7 Flavours
# 26    $98.91       $109.90                1 Sizes
# 27    $79.95        $99.94   3 Sizes | 3 Flavours
# 28    $37.71        $41.90             4 Flavours
# 29   $125.96       $139.95   1 Sizes | 7 Flavours
# 30    $74.66        $82.95   2 Sizes | 2 Flavours
# 31    $27.97        $39.95  4 Sizes | 11 Flavours
# 32    $34.97        $49.95  3 Sizes | 11 Flavours
# 33    $27.19        $33.99   3 Sizes | 2 Flavours
# 34    $75.42        $83.80                1 Sizes
# 35    $94.35       $117.94             2 Flavours
# 36     $5.94         $6.60   2 Sizes | 5 Flavours
# 37    $71.95        $89.94             5 Flavours
# 38   $152.96       $169.95   1 Sizes | 8 Flavours
# 39   $127.95       $159.94             4 Flavours
# 40    $55.21        $84.94  2 Sizes | 10 Flavours
# 41   $151.95       $189.94             2 Flavours
# 42    $89.09        $98.99             5 Flavours
# 43   $143.96       $159.95             5 Flavours
# 44    $45.86        $50.95             6 Flavours
# 45    $44.96        $49.95             1 Flavours
# 46    $67.95        $84.94             7 Flavours
# 47    $71.96        $79.95             2 Flavours
# 48    $26.35        $32.94   3 Sizes | 3 Flavours
# 49    $80.96        $89.95   1 Sizes | 9 Flavours
# 50    $31.46        $34.95             5 Flavours
# 51    $41.36        $45.95  2 Sizes | 16 Flavours
# 52    $44.96        $49.95             3 Flavours
# 53     $4.50         $5.00   4 Sizes | 5 Flavours
# 54    $63.19        $78.99            14 Flavours
# 55    $33.14        $38.99   2 Sizes | 5 Flavours
# 56     $2.70         $3.00   4 Sizes | 7 Flavours
# 57     $4.24         $4.99  4 Sizes | 10 Flavours
# 58    $72.20        $84.94             8 Flavours
# 59     $4.05         $4.50   2 Sizes | 8 Flavours
# 60   $134.94       $159.94             5 Flavours
# 61   $110.45       $129.94             4 Flavours
# 62    $57.84        $88.99            14 Flavours
# 63    $41.36        $45.95             5 Flavours
# 64   $127.95       $159.94             3 Flavours
# 65     $3.92         $4.90   3 Sizes | 3 Flavours
# 66   $103.98       $129.98             2 Flavours
# 67    $79.95        $99.94             3 Flavours
# 68    $91.95       $114.94   1 Sizes | 2 Flavours
# 69    $62.96        $69.95             4 Flavours
# 70   $107.96       $119.95             5 Flavours
# 71    $74.24        $98.99            10 Flavours
# 72    $47.95        $59.94  5 Sizes | 22 Flavours
# 73    $49.46        $54.95             7 Flavours
# 74    $98.91       $109.90                1 Sizes
# 75    $79.95        $99.94   3 Sizes | 3 Flavours
# 76    $37.71        $41.90             4 Flavours
# 77   $125.96       $139.95   1 Sizes | 7 Flavours
# 78    $74.66        $82.95   2 Sizes | 2 Flavours
# 79    $27.97        $39.95  4 Sizes | 11 Flavours
# 80    $34.97        $49.95  3 Sizes | 11 Flavours
# 81    $27.19        $33.99   3 Sizes | 2 Flavours
# 82    $75.42        $83.80                1 Sizes
# 83    $94.35       $117.94             2 Flavours
# 84     $5.94         $6.60   2 Sizes | 5 Flavours
# 85    $71.95        $89.94             5 Flavours
# 86   $152.96       $169.95   1 Sizes | 8 Flavours
# 87   $127.95       $159.94             4 Flavours
# 88    $55.21        $84.94  2 Sizes | 10 Flavours
# 89   $151.95       $189.94             2 Flavours
# 90    $89.09        $98.99             5 Flavours
# 91   $143.96       $159.95             5 Flavours
# 92    $45.86        $50.95             6 Flavours
# 93    $44.96        $49.95             1 Flavours
# 94    $67.95        $84.94             7 Flavours
# 95    $71.96        $79.95             2 Flavours
# 96   $118.99       $138.99   2 Sizes | 4 Flavours
# 97    $63.19        $78.99             2 Flavours
# 98    $79.19        $89.94            22 Flavours
# 99    $76.42        $89.90   2 Sizes | 4 Flavours
# 100  $183.95       $229.94             2 Flavours
# 89   https://www.sportsfuel.co.nz/products/nuzest-c...
# 90   https://www.sportsfuel.co.nz/products/mutantwh...
# 91   https://www.sportsfuel.co.nz/products/mutant-m...
# 92   https://www.sportsfuel.co.nz/products/nothing-...
# 93   https://www.sportsfuel.co.nz/products/nothingn...
# 94   https://www.sportsfuel.co.nz/products/ehp-oxyw...
# 95   https://www.sportsfuel.co.nz/products/nothing-...
# 96   https://www.sportsfuel.co.nz/products/muscleph...
# 97   https://www.sportsfuel.co.nz/products/balance-...
# 98   https://www.sportsfuel.co.nz/products/musclesp...
# 99   https://www.sportsfuel.co.nz/products/sis-rapi...
# 100  https://www.sportsfuel.co.nz/products/optimum-...
# 101  https://www.sportsfuel.co.nz/products/chief-co...
# 102  https://www.sportsfuel.co.nz/products/balance-...
# 103  https://www.sportsfuel.co.nz/products/musclete...
# 104  https://www.sportsfuel.co.nz/products/mutant-m...
# 105  https://www.sportsfuel.co.nz/products/optimum-...
# 106  https://www.sportsfuel.co.nz/products/musashi-...
# 107  https://www.sportsfuel.co.nz/products/pack-nut...
# 108  https://www.sportsfuel.co.nz/products/balance-...
# 109  https://www.sportsfuel.co.nz/products/horleys-...
# 110  https://www.sportsfuel.co.nz/products/pranaonp...
# 111  https://www.sportsfuel.co.nz/products/balance-...
# 112  https://www.sportsfuel.co.nz/products/macro-mi...
# 113  https://www.sportsfuel.co.nz/products/bsn-synt...
# 114  https://www.sportsfuel.co.nz/products/switch-n...
# 115  https://www.sportsfuel.co.nz/products/nothing-...
# 116  https://www.sportsfuel.co.nz/products/musclete...
# 117  https://www.sportsfuel.co.nz/products/ehp-labs...
# 118  https://www.sportsfuel.co.nz/products/ehp-bles...
# 119  https://www.sportsfuel.co.nz/products/clean-nu...

# %% [markdown]
# ### 1. Price per gram for a product

# %%
import pandas as pd
import re

# Extract weight from name
def extract_grams(name):
    name = name.lower()
    match = re.search(r'(\d+\.?\d*)\s*(kg|g|lb|lbs)', name)
    if not match:
        return None
    quantity, unit = match.groups()
    quantity = float(quantity)
    
    if unit == 'kg':
        return quantity * 1000
    elif unit == 'g':
        return quantity
    elif unit in ['lb', 'lbs']:
        return quantity * 453.592
    return None

df['weight_g'] = df['name'].apply(extract_grams)

# %%
df
# Out:
#                                                   name                  type  \
# 0    Optimum Nutrition Gold Standard 100% Whey Prot...          Whey Protein
# 1              Clean Nutrition Whey Protein Powder 1kg          Whey Protein
# 2              Clean Nutrition Whey Protein Powder 2kg          Whey Protein
# 3    Optimum Nutrition Gold Standard 100% Whey Isolate  Whey Protein Isolate
# 4               Clean Nutrition Pea Protein Powder 1kg         Plant Protein
# ..                                                 ...                   ...
# 115                       Nothing Naughty Collagen Bar              Collagen
# 116                         MuscleTech Mass Tech Elite           Mass Gainer
# 117           EHP Labs IsoPept Whey Protein Powder 2lb  Whey Protein Isolate
# 118                 EHP Labs Blessed Plant Protein 2lb         Plant Protein
# 119                  Clean Nutrition Fava Bean Protein         Plant Protein
#
#       price compare_price                options  \
# 0    $47.95        $59.94  5 Sizes | 22 Flavours
# 1    $49.46        $54.95             7 Flavours
# 2    $98.91       $109.90                1 Sizes
# 3    $79.95        $99.94   3 Sizes | 3 Flavours
# 4    $37.71        $41.90             4 Flavours
# ..      ...           ...                    ...
# 115   $2.70         $3.00                2 Sizes
# 116  $65.97       $119.95   2 Sizes | 5 Flavours
# 117  $67.95        $84.94             4 Flavours
# 118  $59.95        $74.94             7 Flavours
# 119  $31.46        $34.95             4 Flavours
#
#                                                    url  weight_g
# 0    https://www.sportsfuel.co.nz/products/optimum-...       NaN
# 1    https://www.sportsfuel.co.nz/products/clean-nu...  1000.000
# 2    https://www.sportsfuel.co.nz/products/clean-nu...  2000.000
# 3    https://www.sportsfuel.co.nz/products/optimum-...       NaN
# 4    https://www.sportsfuel.co.nz/products/clean-nu...  1000.000
# ..                                                 ...       ...
# 115  https://www.sportsfuel.co.nz/products/nothing-...       NaN
# 116  https://www.sportsfuel.co.nz/products/musclete...       NaN
# 117  https://www.sportsfuel.co.nz/products/ehp-labs...   907.184
# 118  https://www.sportsfuel.co.nz/products/ehp-bles...   907.184
# 119  https://www.sportsfuel.co.nz/products/clean-nu...       NaN
#
# [120 rows x 7 columns]

# %%
df['discounted_price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)

# Calculate price per gram
df['price_per_g'] = df.apply(lambda row: round(row['discounted_price'] / row['weight_g'], 3) if row['weight_g'] else None, axis=1)

# Show result
print(df[['name', 'discounted_price', 'weight_g', 'price_per_g']])
# Out:
#                                                   name  discounted_price  \
# 0    Optimum Nutrition Gold Standard 100% Whey Prot...             47.95
# 1              Clean Nutrition Whey Protein Powder 1kg             49.46
# 2              Clean Nutrition Whey Protein Powder 2kg             98.91
# 3    Optimum Nutrition Gold Standard 100% Whey Isolate             79.95
# 4               Clean Nutrition Pea Protein Powder 1kg             37.71
# ..                                                 ...               ...
# 115                       Nothing Naughty Collagen Bar              2.70
# 116                         MuscleTech Mass Tech Elite             65.97
# 117           EHP Labs IsoPept Whey Protein Powder 2lb             67.95
# 118                 EHP Labs Blessed Plant Protein 2lb             59.95
# 119                  Clean Nutrition Fava Bean Protein             31.46
#
#      weight_g  price_per_g
# 0         NaN          NaN
# 1    1000.000        0.049
# 2    2000.000        0.049
# 3         NaN          NaN
# 4    1000.000        0.038
# ..        ...          ...
# 115       NaN          NaN
# 116       NaN          NaN
# 117   907.184        0.075
# 118   907.184        0.066
# 119       NaN          NaN
#
# [120 rows x 4 columns]
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/st/hvtfb7zs01v76f2gqkcmf1800000gn/T/ipykernel_16452/2532403394.py:1: SyntaxWarning: invalid escape sequence '\$'
#   df['discounted_price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
# Count NaNs in each column
print(df.isna().sum())
# 110                         PranaOn Phyto Fire Protein         Plant Protein
# 112               Macro Mike Plant Protein Sample Pack         Plant Protein
# 114                   Switch Nutrition Collagen Switch              Collagen
# 115                       Nothing Naughty Collagen Bar              Collagen
# 116                         MuscleTech Mass Tech Elite           Mass Gainer
# 119                  Clean Nutrition Fava Bean Protein         Plant Protein
#
#        price compare_price                options  \
# 0     $47.95        $59.94  5 Sizes | 22 Flavours
# 3     $79.95        $99.94   3 Sizes | 3 Flavours
# 6     $74.66        $82.95   2 Sizes | 2 Flavours
# 7     $27.97        $39.95  4 Sizes | 11 Flavours
# 8     $34.97        $49.95  3 Sizes | 11 Flavours
# 9     $27.19        $33.99   3 Sizes | 2 Flavours
# 12     $5.94         $6.60   2 Sizes | 5 Flavours
# 14   $152.96       $169.95   1 Sizes | 8 Flavours
# 16    $55.21        $84.94  2 Sizes | 10 Flavours
# 24    $47.95        $59.94  5 Sizes | 22 Flavours
# 27    $79.95        $99.94   3 Sizes | 3 Flavours
# 30    $74.66        $82.95   2 Sizes | 2 Flavours
# 31    $27.97        $39.95  4 Sizes | 11 Flavours
# 32    $34.97        $49.95  3 Sizes | 11 Flavours
# 33    $27.19        $33.99   3 Sizes | 2 Flavours
# 36     $5.94         $6.60   2 Sizes | 5 Flavours
# 38   $152.96       $169.95   1 Sizes | 8 Flavours
# 40    $55.21        $84.94  2 Sizes | 10 Flavours
# 48    $26.35        $32.94   3 Sizes | 3 Flavours
# 51    $41.36        $45.95  2 Sizes | 16 Flavours
# 53     $4.50         $5.00   4 Sizes | 5 Flavours
# 55    $33.14        $38.99   2 Sizes | 5 Flavours
# 56     $2.70         $3.00   4 Sizes | 7 Flavours
# 57     $4.24         $4.99  4 Sizes | 10 Flavours
# 59     $4.05         $4.50   2 Sizes | 8 Flavours
# 62    $57.84        $88.99            14 Flavours
# 65     $3.92         $4.90   3 Sizes | 3 Flavours
# 69    $62.96        $69.95             4 Flavours
# 72    $47.95        $59.94  5 Sizes | 22 Flavours
# 75    $79.95        $99.94   3 Sizes | 3 Flavours
# 78    $74.66        $82.95   2 Sizes | 2 Flavours
# 79    $27.97        $39.95  4 Sizes | 11 Flavours
# 80    $34.97        $49.95  3 Sizes | 11 Flavours
# 81    $27.19        $33.99   3 Sizes | 2 Flavours
# 84     $5.94         $6.60   2 Sizes | 5 Flavours
# 86   $152.96       $169.95   1 Sizes | 8 Flavours
# 88    $55.21        $84.94  2 Sizes | 10 Flavours
# 96   $118.99       $138.99   2 Sizes | 4 Flavours
# 101   $44.80        $56.00   1 Sizes | 3 Flavours
# 107   $12.50        $25.00   2 Sizes | 4 Flavours
# 109   $92.64       $108.99   2 Sizes | 4 Flavours
# 110    $2.25         $2.50   3 Sizes | 5 Flavours
# 112   $41.64        $48.99
# 114   $35.95        $44.94   2 Sizes | 5 Flavours
# 115    $2.70         $3.00                2 Sizes
# 116   $65.97       $119.95   2 Sizes | 5 Flavours
# 116  https://www.sportsfuel.co.nz/products/musclete...       NaN
# 119  https://www.sportsfuel.co.nz/products/clean-nu...       NaN
#
#      discounted_price  price_per_g
# 0               47.95          NaN
# 3               79.95          NaN
# 6               74.66          NaN
# 7               27.97          NaN
# 8               34.97          NaN
# 9               27.19          NaN
# 12               5.94          NaN
# 14             152.96          NaN
# 16              55.21          NaN
# 24              47.95          NaN
# 27              79.95          NaN
# 30              74.66          NaN
# 31              27.97          NaN
# 32              34.97          NaN
# 33              27.19          NaN
# 36               5.94          NaN
# 38             152.96          NaN
# 40              55.21          NaN
# 48              26.35          NaN
# 51              41.36          NaN
# 53               4.50          NaN
# 55              33.14          NaN
# 56               2.70          NaN
# 57               4.24          NaN
# 59               4.05          NaN
# 62              57.84          NaN
# 65               3.92          NaN
# 69              62.96          NaN
# 72              47.95          NaN
# 75              79.95          NaN
# 78              74.66          NaN
# 79              27.97          NaN
# 80              34.97          NaN
# 81              27.19          NaN
# 84               5.94          NaN
# 86             152.96          NaN
# 88              55.21          NaN
# 96             118.99          NaN
# 101             44.80          NaN
# 107             12.50          NaN
# 109             92.64          NaN
# 110              2.25          NaN
# 112             41.64          NaN
# 114             35.95          NaN
# 115              2.70          NaN
# 116             65.97          NaN
# 119             31.46          NaN

# %%
# removing rows with missing values
df_cleaned = df.dropna()
df_cleaned.head()
# Out:
#                                                  name           type    price  \
# 1             Clean Nutrition Whey Protein Powder 1kg   Whey Protein   $49.46
# 2             Clean Nutrition Whey Protein Powder 2kg   Whey Protein   $98.91
# 4              Clean Nutrition Pea Protein Powder 1kg  Plant Protein   $37.71
# 5   MuscleTech Nitro Tech 100% Whey Gold Protein P...   Whey Protein  $125.96
# 10             Clean Nutrition Pea Protein Powder 2kg  Plant Protein   $75.42
#
#    compare_price               options  \
# 1         $54.95            7 Flavours
# 2        $109.90               1 Sizes
# 4         $41.90            4 Flavours
# 5        $139.95  1 Sizes | 7 Flavours
# 10        $83.80               1 Sizes
#
#                                                   url  weight_g  \
# 1   https://www.sportsfuel.co.nz/products/clean-nu...   1000.00
# 2   https://www.sportsfuel.co.nz/products/clean-nu...   2000.00
# 4   https://www.sportsfuel.co.nz/products/clean-nu...   1000.00
# 5   https://www.sportsfuel.co.nz/products/nitro-te...   2267.96
# 10  https://www.sportsfuel.co.nz/products/clean-nu...   2000.00
#
#     discounted_price  price_per_g
# 1              49.46        0.049
# 2              98.91        0.049
# 4              37.71        0.038
# 5             125.96        0.056
# 10             75.42        0.038

# %%
df_cleaned = df_cleaned.rename(columns={
    'name':'Product Name',
    'type':'Type',
    'price':'Disc_Price',
    'compare_price':'Original Price',
    'options' : 'Options',
    'url': 'URL',
    'weight_g':'Weight_in_grams',
    'price_per_g':'Price_per_gram'
})
#del df_cleaned['discounted_price']
df_cleaned.head()
# Out:
#                                          Product Name           Type  \
# 1             Clean Nutrition Whey Protein Powder 1kg   Whey Protein
# 2             Clean Nutrition Whey Protein Powder 2kg   Whey Protein
# 4              Clean Nutrition Pea Protein Powder 1kg  Plant Protein
# 5   MuscleTech Nitro Tech 100% Whey Gold Protein P...   Whey Protein
# 10             Clean Nutrition Pea Protein Powder 2kg  Plant Protein
#
#    Disc_Price Original Price               Options  \
# 1      $49.46         $54.95            7 Flavours
# 2      $98.91        $109.90               1 Sizes
# 4      $37.71         $41.90            4 Flavours
# 5     $125.96        $139.95  1 Sizes | 7 Flavours
# 10     $75.42         $83.80               1 Sizes
#
#                                                   URL  Weight_in_grams  \
# 1   https://www.sportsfuel.co.nz/products/clean-nu...          1000.00
# 2   https://www.sportsfuel.co.nz/products/clean-nu...          2000.00
# 4   https://www.sportsfuel.co.nz/products/clean-nu...          1000.00
# 5   https://www.sportsfuel.co.nz/products/nitro-te...          2267.96
# 10  https://www.sportsfuel.co.nz/products/clean-nu...          2000.00
#
#     discounted_price  Price_per_gram
# 1              49.46           0.049
# 2              98.91           0.049
# 4              37.71           0.038
# 5             125.96           0.056
# 10             75.42           0.038

# %%
# Creating 2 columns- NUmber of Sizes available for a product, Flavours it offers.

# First, remove leading/trailing spaces
df_cleaned['Options'] = df_cleaned['Options'].str.strip()

# Split the column into 'size_options' and 'flavour_options'
df_cleaned['Size Options'] = df_cleaned['Options'].str.extract(r'(\d+)\s+Size[s]?', expand=False).astype(float)
df_cleaned['Flavours'] = df_cleaned['Options'].str.extract(r'(\d+)\s+Flavour[s]?', expand=False).astype(float)

# %%
df_cleaned[['Size Options', 'Flavours']] = df_cleaned[['Size Options', 'Flavours']].fillna(0)

# Reset your DataFrame index 
df_cleaned = df_cleaned.reset_index(drop=True) 
df_cleaned.index = df_cleaned.index + 1 
df_cleaned.head()
# Out:
#                                         Product Name           Type  \
# 1            Clean Nutrition Whey Protein Powder 1kg   Whey Protein
# 2            Clean Nutrition Whey Protein Powder 2kg   Whey Protein
# 3             Clean Nutrition Pea Protein Powder 1kg  Plant Protein
# 4  MuscleTech Nitro Tech 100% Whey Gold Protein P...   Whey Protein
# 5             Clean Nutrition Pea Protein Powder 2kg  Plant Protein
#
#   Disc_Price Original Price  \
# 1     $49.46         $54.95
# 2     $98.91        $109.90
# 3     $37.71         $41.90
# 4    $125.96        $139.95
# 5     $75.42         $83.80
#
#                                                  URL  Weight_in_grams  \
# 1  https://www.sportsfuel.co.nz/products/clean-nu...          1000.00
# 2  https://www.sportsfuel.co.nz/products/clean-nu...          2000.00
# 3  https://www.sportsfuel.co.nz/products/clean-nu...          1000.00
# 4  https://www.sportsfuel.co.nz/products/nitro-te...          2267.96
# 5  https://www.sportsfuel.co.nz/products/clean-nu...          2000.00
#
#    discounted_price  Price_per_gram  Size Options  Flavours
# 1             49.46           0.049           0.0       7.0
# 2             98.91           0.049           1.0       0.0
# 3             37.71           0.038           0.0       4.0
# 4            125.96           0.056           1.0       7.0
# 5             75.42           0.038           1.0       0.0

# %%
df_cleaned.to_csv("SportsFuel_products.csv", index=False)
